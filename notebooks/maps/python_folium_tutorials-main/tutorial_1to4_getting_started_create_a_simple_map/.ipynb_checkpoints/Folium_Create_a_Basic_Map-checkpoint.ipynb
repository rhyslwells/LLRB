# %% [markdown]
# # Install/Import Packages

# %%
#!pip install folium
#!pip install pandas

# %%
import pandas as pd
import folium

# %% [markdown]
# # Load and View Pandas Dataframe

# %%
# define file location
# file can be downloaded at URL: https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2/about_data
input_data = "D:/Tutorials/data/Crimes_-_2001_to_Present_20231109.csv"

# %%
# create dataframe
df = pd.read_csv(input_data)

# %%
# preview dataframe
#df.head()
df.tail()
# Out:
#                ID Case Number                    Date  \
# 7930141  12131776    JD327752  08/10/2020 08:30:00 PM
# 7930142  12082414    JD269218  06/18/2020 09:00:00 PM
# 7930143  12118237    JD311791  07/27/2020 03:02:00 PM
# 7930144  12142591    JD340297  08/14/2020 03:00:00 PM
# 7930145  12002171    JD177406  03/06/2020 02:00:00 PM
#
#                                        Block  IUCR         Primary Type  \
# 7930141               066XX S SACRAMENTO AVE  0620             BURGLARY
# 7930142  093XX S DR MARTIN LUTHER KING JR DR  0820                THEFT
# 7930143                      033XX W POLK ST  0486              BATTERY
# 7930144                 023XX W ROSEMONT AVE  0910  MOTOR VEHICLE THEFT
# 7930145                 033XX N LAKEWOOD AVE  1150   DECEPTIVE PRACTICE
#
#                      Description Location Description  Arrest  Domestic  ...  \
# 7930141           UNLAWFUL ENTRY            APARTMENT   False     False  ...
# 7930142           $500 AND UNDER            RESIDENCE   False     False  ...
# 7930143  DOMESTIC BATTERY SIMPLE            APARTMENT   False      True  ...
# 7930144               AUTOMOBILE               STREET   False     False  ...
# 7930145        CREDIT CARD FRAUD            APARTMENT   False     False  ...
#
#          Ward  Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 7930141  17.0            66.0        05     1157527.0    1860392.0  2020
# 7930142   9.0            49.0        06     1180558.0    1843036.0  2020
# 7930143  24.0            27.0       08B     1154169.0    1896171.0  2020
# 7930144  50.0             2.0        07     1159419.0    1941765.0  2020
# 7930145  44.0             6.0        11     1167040.0    1922212.0  2020
#
#                      Updated On   Latitude  Longitude  \
# 7930141  08/17/2020 03:41:32 PM  41.772671 -87.698104
# 7930142  06/25/2020 03:41:40 PM  41.724546 -87.614211
# 7930143  08/03/2020 03:41:51 PM  41.870921 -87.709461
# 7930144  08/26/2020 03:40:41 PM  41.995927 -87.688929
# 7930145  03/13/2020 03:41:29 PM  41.942112 -87.661459
#
#                               Location
# 7930141  (41.772671069, -87.698104059)
# 7930142  (41.724546436, -87.614210743)
# 7930143  (41.870920735, -87.709461362)
# 7930144  (41.995927389, -87.688928533)
# 7930145  (41.942112495, -87.661458579)
#
# [5 rows x 22 columns]

# %% [markdown]
# # Create a Folium Map - Tutorial 1

# %%
# create map
#41.8781° N, 87.6298° W
m = folium.Map(location=(41.8781, -87.6298))

# %%
# display map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfd0c3a7a4768726ef226f6a98249018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfd0c3a7a4768726ef226f6a98249018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfd0c3a7a4768726ef226f6a98249018 = L.map(
#                 &quot;map_dfd0c3a7a4768726ef226f6a98249018&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_047c54fae5a150dbb5fd4bf259df55f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_047c54fae5a150dbb5fd4bf259df55f0.addTo(map_dfd0c3a7a4768726ef226f6a98249018);
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add a Single Point - Tutorial 2

# %%
# m = folium.Map([45.35, -121.6972], zoom_start=12)

# folium.Marker(
#     location=[45.3288, -121.6625],
#     tooltip="Click me!",
#     popup="Mt. Hood Meadows",
#     icon=folium.Icon(icon="cloud"),
# ).add_to(m)

# folium.Marker(
#     location=[45.3311, -121.7113],
#     tooltip="Click me!",
#     popup="Timberline Lodge",
#     icon=folium.Icon(color="green"),
# ).add_to(m)

# m

# [lat, long]
point1 = [41.772671, -87.698104]

folium.Marker(
    location = point1,
    tooltip="Have fun with python folium!",
    popup="Add a single point tutorial",
    icon=folium.Icon(color="green"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfd0c3a7a4768726ef226f6a98249018 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfd0c3a7a4768726ef226f6a98249018&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfd0c3a7a4768726ef226f6a98249018 = L.map(
#                 &quot;map_dfd0c3a7a4768726ef226f6a98249018&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_047c54fae5a150dbb5fd4bf259df55f0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_047c54fae5a150dbb5fd4bf259df55f0.addTo(map_dfd0c3a7a4768726ef226f6a98249018);
#
#             var marker_5413d57c3b979e8516e46f99fa8bc89d = L.marker(
#                 [41.772671, -87.698104],
#                 {}
#             ).addTo(map_dfd0c3a7a4768726ef226f6a98249018);
#
#
#             var icon_ee86214b7e5c30537f761d064333d589 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5413d57c3b979e8516e46f99fa8bc89d.setIcon(icon_ee86214b7e5c30537f761d064333d589);
#
#
#         var popup_d487657ffec80c82a71038d59c7b0ede = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37ffcb3ecdd17b11510f529394632a13 = $(`&lt;div id=&quot;html_37ffcb3ecdd17b11510f529394632a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_d487657ffec80c82a71038d59c7b0ede.setContent(html_37ffcb3ecdd17b11510f529394632a13);
#
#
#
#         marker_5413d57c3b979e8516e46f99fa8bc89d.bindPopup(popup_d487657ffec80c82a71038d59c7b0ede)
#         ;
#
#
#
#
#             marker_5413d57c3b979e8516e46f99fa8bc89d.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Add 5 Points - Tutorial 2

# %%
# Add all 5 points manually
# create map
#41.8781° N, 87.6298° W
m1 = folium.Map(location=(41.8781, -87.6298))

# [lat,long]
point1=[41.772671,-87.698104]
point2=[41.724546,-87.614211]
point3=[41.870921,-87.709461]
point4=[41.995927,-87.688929]
point5=[41.942112,-87.661459]

# add point 1
folium.Marker(
    location = point1,
    tooltip="Have fun with python folium!",
    popup="Add a single point tutorial",
    icon=folium.Icon(color="green"),
).add_to(m1)

# add point 2
folium.Marker(
    location = point2,
    tooltip="Have fun with python folium!",
    popup="Add a single point tutorial",
    icon=folium.Icon(color="red"),
).add_to(m1)

# add point 3
folium.Marker(
    location = point3,
    tooltip="Have fun with python folium!",
    popup="Add a single point tutorial",
    icon=folium.Icon(color="blue"),
).add_to(m1)

# add point 4
folium.Marker(
    location = point4,
    tooltip="Have fun with python folium!",
    popup="Add a single point tutorial",
    icon=folium.Icon(color="pink"),
).add_to(m1)

# add point 5
folium.Marker(
    location = point5,
    tooltip="Have fun with python folium!",
    popup="Add a single point tutorial",
    icon=folium.Icon(color="purple"),
).add_to(m1)

m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc2c7d5af1347e73a0119c7ba4498039 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc2c7d5af1347e73a0119c7ba4498039&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc2c7d5af1347e73a0119c7ba4498039 = L.map(
#                 &quot;map_dc2c7d5af1347e73a0119c7ba4498039&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c79e63aa063f74f5b59bb3233e18bf95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_c79e63aa063f74f5b59bb3233e18bf95.addTo(map_dc2c7d5af1347e73a0119c7ba4498039);
#
#             var marker_18c0297bd4f632b5e9255cabef2b03bc = L.marker(
#                 [41.772671, -87.698104],
#                 {}
#             ).addTo(map_dc2c7d5af1347e73a0119c7ba4498039);
#
#
#             var icon_8698cd6e7ea2cb23e0af295e67646075 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_18c0297bd4f632b5e9255cabef2b03bc.setIcon(icon_8698cd6e7ea2cb23e0af295e67646075);
#
#
#         var popup_27a017703bdc208fce2ac050573e0262 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd661facb4af6024d4a37ab8ede1fa4a = $(`&lt;div id=&quot;html_cd661facb4af6024d4a37ab8ede1fa4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_27a017703bdc208fce2ac050573e0262.setContent(html_cd661facb4af6024d4a37ab8ede1fa4a);
#
#
#
#         marker_18c0297bd4f632b5e9255cabef2b03bc.bindPopup(popup_27a017703bdc208fce2ac050573e0262)
#         ;
#
#
#
#
#             marker_18c0297bd4f632b5e9255cabef2b03bc.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_467511a623a145c877f6dd464b8ebfe1 = L.marker(
#                 [41.724546, -87.614211],
#                 {}
#             ).addTo(map_dc2c7d5af1347e73a0119c7ba4498039);
#
#
#             var icon_96c1491b48fa8abe741cc84fd75c943a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_467511a623a145c877f6dd464b8ebfe1.setIcon(icon_96c1491b48fa8abe741cc84fd75c943a);
#
#
#         var popup_48b67c32795c588096cb41fd81df7478 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_404e0025776b35f2691f1ddf8b5005f1 = $(`&lt;div id=&quot;html_404e0025776b35f2691f1ddf8b5005f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_48b67c32795c588096cb41fd81df7478.setContent(html_404e0025776b35f2691f1ddf8b5005f1);
#
#
#
#         marker_467511a623a145c877f6dd464b8ebfe1.bindPopup(popup_48b67c32795c588096cb41fd81df7478)
#         ;
#
#
#
#
#             marker_467511a623a145c877f6dd464b8ebfe1.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_518c94e8fe35aed1534ef56152092916 = L.marker(
#                 [41.870921, -87.709461],
#                 {}
#             ).addTo(map_dc2c7d5af1347e73a0119c7ba4498039);
#
#
#             var icon_c36a623573e41e53f91998761d32b0b2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_518c94e8fe35aed1534ef56152092916.setIcon(icon_c36a623573e41e53f91998761d32b0b2);
#
#
#         var popup_62f84b26ec4d7274e6bd66e5cbc351ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eeb0b65670eb63799dd9459865c4c062 = $(`&lt;div id=&quot;html_eeb0b65670eb63799dd9459865c4c062&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_62f84

# %%
# Use a list to add 5 points
m2 = folium.Map(location=(41.8781, -87.6298))

# Create a new dataframe called df_last5 that contains
#the last 5 rows of original dataframe df
df_last5 = df.tail()

df_last5.head()

# python zip function allows us to iterate through multiple lists at the same time
# we want to iterate through the latitude and longitude columns at the same time
for lat, lng in zip(df_last5.Latitude, df_last5.Longitude):
    folium.Marker(
        location=[lat,lng],
        tooltip="Have fun with python folium!",
        popup="Add a single point tutorial",
        icon=folium.Icon(color="blue"),
    ).add_to(m2)
    
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98d009216e96900c4d58caa14d6aa930 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98d009216e96900c4d58caa14d6aa930&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98d009216e96900c4d58caa14d6aa930 = L.map(
#                 &quot;map_98d009216e96900c4d58caa14d6aa930&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd6d6e5c7ed63521cc3e54bc1eca6b9c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_bd6d6e5c7ed63521cc3e54bc1eca6b9c.addTo(map_98d009216e96900c4d58caa14d6aa930);
#
#             var marker_2f2498c8aadfee2df9320a0f9ea6ccff = L.marker(
#                 [41.772671069, -87.698104059],
#                 {}
#             ).addTo(map_98d009216e96900c4d58caa14d6aa930);
#
#
#             var icon_a701535557a9f6ac80456c7499e2fc71 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2f2498c8aadfee2df9320a0f9ea6ccff.setIcon(icon_a701535557a9f6ac80456c7499e2fc71);
#
#
#         var popup_9e9c7486f0afd3e2bd4332552790c7d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc3b992a1c1a457212e7cc136d242418 = $(`&lt;div id=&quot;html_fc3b992a1c1a457212e7cc136d242418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_9e9c7486f0afd3e2bd4332552790c7d1.setContent(html_fc3b992a1c1a457212e7cc136d242418);
#
#
#
#         marker_2f2498c8aadfee2df9320a0f9ea6ccff.bindPopup(popup_9e9c7486f0afd3e2bd4332552790c7d1)
#         ;
#
#
#
#
#             marker_2f2498c8aadfee2df9320a0f9ea6ccff.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d07b08bb80e4185672cde96e32312714 = L.marker(
#                 [41.724546436, -87.614210743],
#                 {}
#             ).addTo(map_98d009216e96900c4d58caa14d6aa930);
#
#
#             var icon_8d7e64c2a8029db243c2111faece5a1f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d07b08bb80e4185672cde96e32312714.setIcon(icon_8d7e64c2a8029db243c2111faece5a1f);
#
#
#         var popup_98b71bec0c98549cc6e3b0fa33822f3d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9b9946940acd107f882be22bc0ed40e2 = $(`&lt;div id=&quot;html_9b9946940acd107f882be22bc0ed40e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_98b71bec0c98549cc6e3b0fa33822f3d.setContent(html_9b9946940acd107f882be22bc0ed40e2);
#
#
#
#         marker_d07b08bb80e4185672cde96e32312714.bindPopup(popup_98b71bec0c98549cc6e3b0fa33822f3d)
#         ;
#
#
#
#
#             marker_d07b08bb80e4185672cde96e32312714.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_06533a3c0b14458ae75bf963b4a16cf8 = L.marker(
#                 [41.870920735, -87.709461362],
#                 {}
#             ).addTo(map_98d009216e96900c4d58caa14d6aa930);
#
#
#             var icon_2d7f852fb0513e03a170c1b43337e34b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_06533a3c0b14458ae75bf963b4a16cf8.setIcon(icon_2d7f852fb0513e03a170c1b43337e34b);
#
#
#         var popup_852dd666bf275d1ffec750132e5864d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3abfa90c99e7d15380eea52565d939c = $(`&lt;div id=&quot;html_f3abfa90c99e7d15380eea52565d939c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];

# %% [markdown]
# # Add all Points - Tutorial 3

# %%
# use .info() to check how many points are in the dataset
df.info()

# %%
# Add all points as an individual marker

# Step 1: Iterate through initial df using lat/long columns
# Use the python zip function for this (see above)

m3 = folium.Map(location=(41.8781, -87.6298))

for lat, lng in zip(df.Latitude, df.Longitude):
    folium.Marker(
        location=[lat,lng],
        tooltip="Have fun with python folium!",
        popup="Add a single point tutorial",
        icon=folium.Icon(color="blue"),
    ).add_to(m3)
    
m3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 9
#       6 m3 = folium.Map(location=(41.8781, -87.6298))
#       8 for lat, lng in zip(df.Latitude, df.Longitude):
# ----> 9     folium.Marker(
#      10         location=[lat,lng],
#      11         tooltip="Have fun with python folium!",
#      12         popup="Add a single point tutorial",
#      13         icon=folium.Icon(color="blue"),
#      14     ).add_to(m3)
#      16 m3
#
# File ~\anaconda3\envs\folium_tutorial\Lib\site-packages\folium\map.py:367, in Marker.__init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     365 super().__init__()
#     366 self._name = "Marker"
# --> 367 self.location = validate_location(location) if location is not None else None
#     368 self.options = parse_options(
#     369     draggable=draggable or None, autoPan=draggable or None, **kwargs
#     370 )
#     371 if icon is not None:
#
# File ~\anaconda3\envs\folium_tutorial\Lib\site-packages\folium\utilities.py:101, in validate_location(location)
#      96         raise ValueError(
#      97             "Location should consist of two numerical values, "
#      98             f"but {coord!r} of type {type(coord)} is not convertible to float."
#      99         )
#     100     if math.isnan(float(coord)):
# --> 101         raise ValueError("Location values cannot contain NaNs.")
#     102 return [float(x) for x in coords]
#
# ValueError: Location values cannot contain NaNs.

# %%
# We need to clean the data!!!!!!
# To do that, we'll use the pandas dropna function
# use the subset parameter to only drop NaN values from a subset of latitude and longitude columns
df = df.dropna(axis=0, how='any', subset=['Latitude','Longitude'])

# %%
# use df.info() again to see how many records remain after using dropna()
df.info()

# %%
# try original df first
# if it fails, use list indexing to create a smaller dataframe
# in this instance, my final result was a dataframe
# containing the first 1000 records of the original dataframe

df_1000 = df[0:1000]


# Other datasets I tried:
# df_100000 = df[0:100000]
# df_10000 = df[0:10000]

# I struggled with memory and performance issues
# on my PC
# Settled for df[0:1000]

# %%
# use .info() to verify amount of records in the dataframe
df_1000.info()

# %%
# Create a new map (m3) to display df_1000
m3 = folium.Map(location=(41.8781, -87.6298))

for lat, lng in zip(df_1000.Latitude, df_1000.Longitude):
    folium.Marker(
        location=[lat,lng],
        tooltip="Have fun with python folium!",
        popup="Add a single point tutorial",
        icon=folium.Icon(color="blue"),
    ).add_to(m3)
    
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8fb46851d022e9a344bc883e68623ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8fb46851d022e9a344bc883e68623ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8fb46851d022e9a344bc883e68623ed = L.map(
#                 &quot;map_d8fb46851d022e9a344bc883e68623ed&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_989a8a3884d2076eb4892a76ff0a6382 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_989a8a3884d2076eb4892a76ff0a6382.addTo(map_d8fb46851d022e9a344bc883e68623ed);
#
#             var marker_5f7ce19fd255f5e32f9683dc525d8ca3 = L.marker(
#                 [41.830481843, -87.621751752],
#                 {}
#             ).addTo(map_d8fb46851d022e9a344bc883e68623ed);
#
#
#             var icon_452296e1fee0f33b79872de066940794 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5f7ce19fd255f5e32f9683dc525d8ca3.setIcon(icon_452296e1fee0f33b79872de066940794);
#
#
#         var popup_52228c603b546dc2bfa21bfe277a3f04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0b00372162c1a11fc4079639aa48096 = $(`&lt;div id=&quot;html_a0b00372162c1a11fc4079639aa48096&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_52228c603b546dc2bfa21bfe277a3f04.setContent(html_a0b00372162c1a11fc4079639aa48096);
#
#
#
#         marker_5f7ce19fd255f5e32f9683dc525d8ca3.bindPopup(popup_52228c603b546dc2bfa21bfe277a3f04)
#         ;
#
#
#
#
#             marker_5f7ce19fd255f5e32f9683dc525d8ca3.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9054a4e3cb6f5bd579b50d82849589a7 = L.marker(
#                 [41.836310224, -87.639624112],
#                 {}
#             ).addTo(map_d8fb46851d022e9a344bc883e68623ed);
#
#
#             var icon_66c661f319f97dc3900b9d84e420fad5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9054a4e3cb6f5bd579b50d82849589a7.setIcon(icon_66c661f319f97dc3900b9d84e420fad5);
#
#
#         var popup_60cffbc3b769c08a62dd478c76b1fa4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_915171621737f6ba20bd01640d137579 = $(`&lt;div id=&quot;html_915171621737f6ba20bd01640d137579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_60cffbc3b769c08a62dd478c76b1fa4a.setContent(html_915171621737f6ba20bd01640d137579);
#
#
#
#         marker_9054a4e3cb6f5bd579b50d82849589a7.bindPopup(popup_60cffbc3b769c08a62dd478c76b1fa4a)
#         ;
#
#
#
#
#             marker_9054a4e3cb6f5bd579b50d82849589a7.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_235ec3eecb2b11ad159c22f224c1cea7 = L.marker(
#                 [41.747609555, -87.549179329],
#                 {}
#             ).addTo(map_d8fb46851d022e9a344bc883e68623ed);
#
#
#             var icon_40a004cc183d11c26ab4c519a03d75ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_235ec3eecb2b11ad159c22f224c1cea7.setIcon(icon_40a004cc183d11c26ab4c519a03d75ca);
#
#
#         var popup_66a8dabd94d4718e08e81da7132fdd12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5304797e5c8931d9ccfd84fe1f4a7a3 = $(`&lt;div id=&quot;html_e5304797e5c8931d9ccfd84fe1f4a7a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];

# %% [markdown]
# # Imporve Performance Using Marker Clusters - Tutorial 4

# %%
# Use the Marker Cluster plugin to make the map more navigable
from folium.plugins import MarkerCluster

## Sample code from documentation

# folium.Marker(
#     location=[40.67, -73.94],
#     popup="Add popup text here.",
#     icon=folium.Icon(color="green", icon="ok-sign"),
# ).add_to(marker_cluster)

# define m3 variable
m3 = folium.Map(location=(41.8781, -87.6298))

# create marker_cluster variable
marker_cluster = MarkerCluster().add_to(m3)

#map locations to marker_cluster
for lat, lng in zip(df_1000.Latitude, df_1000.Longitude):
    folium.Marker(
        location=[lat,lng],
        tooltip="Have fun with python folium!",
        popup="Add a single point tutorial",
        icon=folium.Icon(color="blue"),
    ).add_to(marker_cluster)
    
#display m3    
m3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f59582d6de981612a5c71b3a001a0923 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f59582d6de981612a5c71b3a001a0923&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f59582d6de981612a5c71b3a001a0923 = L.map(
#                 &quot;map_f59582d6de981612a5c71b3a001a0923&quot;,
#                 {
#                     center: [41.8781, -87.6298],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77ea3f70bb34ca170ab774b3a0793d89 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_77ea3f70bb34ca170ab774b3a0793d89.addTo(map_f59582d6de981612a5c71b3a001a0923);
#
#             var marker_cluster_0f67e27ca0bbb3321268cc72d29d2ee8 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_672a5f35ea2bb9bdbad541e1b92caf22 = L.marker(
#                 [41.830481843, -87.621751752],
#                 {}
#             ).addTo(marker_cluster_0f67e27ca0bbb3321268cc72d29d2ee8);
#
#
#             var icon_3118c13a2f0ea99a656f9b841261784e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_672a5f35ea2bb9bdbad541e1b92caf22.setIcon(icon_3118c13a2f0ea99a656f9b841261784e);
#
#
#         var popup_bc8e46f5fba46330d004cb57967fde5d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05af3441e4df30fca5dad018c4ff6deb = $(`&lt;div id=&quot;html_05af3441e4df30fca5dad018c4ff6deb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_bc8e46f5fba46330d004cb57967fde5d.setContent(html_05af3441e4df30fca5dad018c4ff6deb);
#
#
#
#         marker_672a5f35ea2bb9bdbad541e1b92caf22.bindPopup(popup_bc8e46f5fba46330d004cb57967fde5d)
#         ;
#
#
#
#
#             marker_672a5f35ea2bb9bdbad541e1b92caf22.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e648264e7994d9ab0b34d3dd0a08f85 = L.marker(
#                 [41.836310224, -87.639624112],
#                 {}
#             ).addTo(marker_cluster_0f67e27ca0bbb3321268cc72d29d2ee8);
#
#
#             var icon_1671c89d9320ac3231fce820160ab079 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5e648264e7994d9ab0b34d3dd0a08f85.setIcon(icon_1671c89d9320ac3231fce820160ab079);
#
#
#         var popup_e41a57dd964487afe16c280bd0d1ed84 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_150222f30bfc36834929452f3eb6c931 = $(`&lt;div id=&quot;html_150222f30bfc36834929452f3eb6c931&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add a single point tutorial&lt;/div&gt;`)[0];
#                 popup_e41a57dd964487afe16c280bd0d1ed84.setContent(html_150222f30bfc36834929452f3eb6c931);
#
#
#
#         marker_5e648264e7994d9ab0b34d3dd0a08f85.bindPopup(popup_e41a57dd964487afe16c280bd0d1ed84)
#         ;
#
#
#
#
#             marker_5e648264e7994d9ab0b34d3dd0a08f85.bindTooltip(
#                 `&lt;div&gt;
#                      Have fun with python folium!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f9df4092727e6afdb702e66b88e319b3 = L.marker(
#                 [41.747609555, -87.549179329],
#                 {}
#             ).addTo(marker_cluster_0f67e27ca0bbb3321268cc72d29d2ee8);
#
#
#             var icon_444702e142c7e43acfb4383f439f5d93 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &q

# %%
# Start with df_5000, then scale up to df_10000
# Compare performance with marker clusters
# vs. performance without marker clusters
df_5000 = df[0:5000]

# %%
m4 = folium.Map(location=(41.8781, -87.6298))

marker_cluster = MarkerCluster().add_to(m4)

for lat, lng in zip(df_5000.Latitude, df_5000.Longitude):
    folium.Marker(
        location=[lat,lng],
        tooltip="Have fun with python folium!",
        popup="Add a single point tutorial",
        icon=folium.Icon(color="blue"),
    ).add_to(marker_cluster)
    
m4

# %%
df_10000 = df[0:10000]

# %%
m5 = folium.Map(location=(41.8781, -87.6298))

marker_cluster = MarkerCluster().add_to(m5)

for lat, lng in zip(df_10000.Latitude, df_10000.Longitude):
    folium.Marker(
        location=[lat,lng],
        tooltip="Have fun with python folium!",
        popup="Add a single point tutorial",
        icon=folium.Icon(color="blue"),
    ).add_to(marker_cluster)
    
m5
